# %% [markdown]
# <a href="https://colab.research.google.com/github/thesimaranjaira/AspectExtraction_SentimentAnalysis/blob/main/tempdelta_actual_summer_scatter_NO4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install energyquantified
# Out:
# Collecting energyquantified
#   Downloading energyquantified-0.7.1-py3-none-any.whl (76 kB)
#      |████████████████████████████████| 76 kB 2.0 MB/s
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.7/dist-packages (from energyquantified) (1.5.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from energyquantified) (2022.1)
# Collecting python-dateutil==2.8.1
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
#      |████████████████████████████████| 227 kB 9.9 MB/s
# Collecting requests==2.25.1
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 3.5 MB/s
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil==2.8.1->energyquantified) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests==2.25.1->energyquantified) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests==2.25.1->energyquantified) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests==2.25.1->energyquantified) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests==2.25.1->energyquantified) (3.0.4)
# Installing collected packages: requests, python-dateutil, energyquantified
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.2
#     Uninstalling python-dateutil-2.8.2:
#       Successfully uninstalled python-dateutil-2.8.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.25.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed energyquantified-0.7.1 python-dateutil-2.8.1 requests-2.25.1

# %%
import pandas as pd
from datetime import timedelta, date
from energyquantified import EnergyQuantified
from energyquantified.time import Frequency
from energyquantified.metadata import Aggregation
from datetime import datetime as dtdatetime
from energyquantified.time import (
   Resolution, Frequency, UTC, get_datetime
)
import matplotlib as mplt
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
api_key = 'ea1244-4926fe-571bed-d0f4b5'
EQ = EnergyQuantified(api_key=api_key)

# %%
from datetime import datetime, time
from energyquantified.time import Frequency

# %%
day_ahead_zero = EQ.timeseries.load(
   'NO4 Consumption Temperature °C H Actual',
   begin='2020-06-01',
   end='2020-08-31',
   #frequency=Frequency.PT1H
)
day_ahead_zero = day_ahead_zero.to_dataframe()

# %%
day_ahead_zero
# Out:
#                           NO4 Consumption Temperature °C H Actual
#
#
# date
# 2020-06-01 00:00:00+02:00                                   10.29
# 2020-06-01 01:00:00+02:00                                    9.66
# 2020-06-01 02:00:00+02:00                                    9.25
# 2020-06-01 03:00:00+02:00                                    9.20
# 2020-06-01 04:00:00+02:00                                    9.70
# ...                                                           ...
# 2020-08-30 19:00:00+02:00                                    8.79
# 2020-08-30 20:00:00+02:00                                    7.75
# 2020-08-30 21:00:00+02:00                                    6.91
# 2020-08-30 22:00:00+02:00                                    6.41
# 2020-08-30 23:00:00+02:00                                    6.31
#
# [2184 rows x 1 columns]

# %%
day_ahead_forecast_twelve = EQ.instances.relative(
   'NO4 Consumption Temperature °C 15min Forecast',
   begin=dtdatetime(2020, 6, 1, 0, 0, 0),
   end=dtdatetime(2020, 8, 31, 0, 0, 0),
   tag='arome',
   days_ahead = 1,  # The day-ahead forecast (0 or higher allowed)
   time_of_day = time(12, 0),  # Issued at exactly 12:00
  #  issued ='earliest',
   frequency = Frequency.PT1H
)
day_ahead_twelve=day_ahead_forecast_twelve.to_dataframe()

# %%
day_ahead_twelve
# Out:
#                           NO4 Consumption Temperature °C 15min Forecast
#
#
# date
# 2020-06-01 00:00:00+02:00                                         10.54
# 2020-06-01 01:00:00+02:00                                         10.09
# 2020-06-01 02:00:00+02:00                                          9.85
# 2020-06-01 03:00:00+02:00                                          9.84
# 2020-06-01 04:00:00+02:00                                         10.30
# ...                                                                 ...
# 2020-08-30 19:00:00+02:00                                          8.46
# 2020-08-30 20:00:00+02:00                                          7.61
# 2020-08-30 21:00:00+02:00                                          6.87
# 2020-08-30 22:00:00+02:00                                          6.25
# 2020-08-30 23:00:00+02:00                                          5.70
#
# [2184 rows x 1 columns]

# %%
df_comb = pd.merge(day_ahead_zero, day_ahead_twelve, left_index=True, right_index=True, how='inner')
df_comb
# Out:
#                           NO4 Consumption Temperature °C H Actual NO4 Consumption Temperature °C 15min Forecast
#
#
# date
# 2020-06-01 00:00:00+02:00                                   10.29                                         10.54
# 2020-06-01 01:00:00+02:00                                    9.66                                         10.09
# 2020-06-01 02:00:00+02:00                                    9.25                                          9.85
# 2020-06-01 03:00:00+02:00                                    9.20                                          9.84
# 2020-06-01 04:00:00+02:00                                    9.70                                         10.30
# ...                                                           ...                                           ...
# 2020-08-30 19:00:00+02:00                                    8.79                                          8.46
# 2020-08-30 20:00:00+02:00                                    7.75                                          7.61
# 2020-08-30 21:00:00+02:00                                    6.91                                          6.87
# 2020-08-30 22:00:00+02:00                                    6.41                                          6.25
# 2020-08-30 23:00:00+02:00                                    6.31                                          5.70
#
# [2184 rows x 2 columns]

# %%
df_comb.columns
# Out:
# MultiIndex([(      'NO4 Consumption Temperature °C H Actual', '', ''),
#             ('NO4 Consumption Temperature °C 15min Forecast', '', '')],
#            )

# %%
df_comb['Temp Delta', '', '']= df_comb['NO4 Consumption Temperature °C H Actual',''] - df_comb['NO4 Consumption Temperature °C 15min Forecast','']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py:399: PerformanceWarning: indexing past lexsort depth may impact performance.
#   user_expressions, allow_stdin)

# %%
df_comb
# Out:
#                           NO4 Consumption Temperature °C H Actual NO4 Consumption Temperature °C 15min Forecast Temp Delta
#
#
# date
# 2020-06-01 00:00:00+02:00                                   10.29                                         10.54      -0.25
# 2020-06-01 01:00:00+02:00                                    9.66                                         10.09      -0.43
# 2020-06-01 02:00:00+02:00                                    9.25                                          9.85      -0.60
# 2020-06-01 03:00:00+02:00                                    9.20                                          9.84      -0.64
# 2020-06-01 04:00:00+02:00                                    9.70                                         10.30      -0.60
# ...                                                           ...                                           ...        ...
# 2020-08-30 19:00:00+02:00                                    8.79                                          8.46       0.33
# 2020-08-30 20:00:00+02:00                                    7.75                                          7.61       0.14
# 2020-08-30 21:00:00+02:00                                    6.91                                          6.87       0.04
# 2020-08-30 22:00:00+02:00                                    6.41                                          6.25       0.16
# 2020-08-30 23:00:00+02:00                                    6.31                                          5.70       0.61
#
# [2184 rows x 3 columns]

# %%
df_comb.columns
# Out:
# MultiIndex([(      'NO4 Consumption Temperature °C H Actual', '', ''),
#             ('NO4 Consumption Temperature °C 15min Forecast', '', ''),
#             (                                   'Temp Delta', '', '')],
#            )

# %%
df_comb.drop(['NO4 Consumption Temperature °C H Actual', 'NO4 Consumption Temperature °C 15min Forecast'], axis=1, level=0 ,inplace=True)
df_comb
# Out:
#                           Temp Delta
#
#
# date
# 2020-06-01 00:00:00+02:00      -0.25
# 2020-06-01 01:00:00+02:00      -0.43
# 2020-06-01 02:00:00+02:00      -0.60
# 2020-06-01 03:00:00+02:00      -0.64
# 2020-06-01 04:00:00+02:00      -0.60
# ...                              ...
# 2020-08-30 19:00:00+02:00       0.33
# 2020-08-30 20:00:00+02:00       0.14
# 2020-08-30 21:00:00+02:00       0.04
# 2020-08-30 22:00:00+02:00       0.16
# 2020-08-30 23:00:00+02:00       0.61
#
# [2184 rows x 1 columns]

# %%
df_comb.columns = ['_'.join(col) for col in df_comb.columns.values]

# %%
df_comb
# Out:
#                            Temp Delta__
# date
# 2020-06-01 00:00:00+02:00         -0.25
# 2020-06-01 01:00:00+02:00         -0.43
# 2020-06-01 02:00:00+02:00         -0.60
# 2020-06-01 03:00:00+02:00         -0.64
# 2020-06-01 04:00:00+02:00         -0.60
# ...                                 ...
# 2020-08-30 19:00:00+02:00          0.33
# 2020-08-30 20:00:00+02:00          0.14
# 2020-08-30 21:00:00+02:00          0.04
# 2020-08-30 22:00:00+02:00          0.16
# 2020-08-30 23:00:00+02:00          0.61
#
# [2184 rows x 1 columns]

# %%
df_comb.columns
# Out:
# Index(['Temp Delta__'], dtype='object')

# %%
spot=(pd.read_csv('/content/drive/My Drive/dataset/market_prices_euro_updated.csv', index_col = ["time"], parse_dates=True).loc[:,"NO4_spot"])
imbalance = (pd.read_csv('/content/drive/My Drive/dataset/market_prices_euro_updated.csv', index_col = ["time"], parse_dates=True).loc[:,"NO4_imbalance"])

# %%
spot=spot.to_frame()
imbalance= imbalance.to_frame()

# %%
spot
# Out:
#                      NO4_spot
# time
# 2018-02-01 00:00:00   0.02552
# 2018-02-01 01:00:00   0.02558
# 2018-02-01 02:00:00   0.02553
# 2018-02-01 03:00:00   0.02573
# 2018-02-01 04:00:00   0.02684
# ...                       ...
# 2021-04-22 08:00:00   0.02250
# 2021-04-22 09:00:00   0.02240
# 2021-04-22 10:00:00   0.02204
# 2021-04-22 11:00:00   0.02200
# 2021-04-22 12:00:00   0.02171
#
# [28584 rows x 1 columns]

# %%
imbalance
# Out:
#                      NO4_imbalance
# time
# 2018-02-01 00:00:00        0.00300
# 2018-02-01 01:00:00        0.00300
# 2018-02-01 02:00:00        0.00300
# 2018-02-01 03:00:00        0.02573
# 2018-02-01 04:00:00        0.02334
# ...                            ...
# 2021-04-22 08:00:00        0.02250
# 2021-04-22 09:00:00        0.02240
# 2021-04-22 10:00:00        0.03157
# 2021-04-22 11:00:00        0.03151
# 2021-04-22 12:00:00        0.02500
#
# [28584 rows x 1 columns]

# %%
imbalance.tz_localize(None)
# Out:
#                      NO4_imbalance
# time
# 2018-02-01 00:00:00        0.00300
# 2018-02-01 01:00:00        0.00300
# 2018-02-01 02:00:00        0.00300
# 2018-02-01 03:00:00        0.02573
# 2018-02-01 04:00:00        0.02334
# ...                            ...
# 2021-04-22 08:00:00        0.02250
# 2021-04-22 09:00:00        0.02240
# 2021-04-22 10:00:00        0.03157
# 2021-04-22 11:00:00        0.03151
# 2021-04-22 12:00:00        0.02500
#
# [28584 rows x 1 columns]

# %%
imbalance.index = pd.to_datetime(imbalance.index, utc=True).tz_convert('Europe/Stockholm')

# %%
imbalance
# Out:
#                            NO4_imbalance
# time
# 2018-02-01 01:00:00+01:00        0.00300
# 2018-02-01 02:00:00+01:00        0.00300
# 2018-02-01 03:00:00+01:00        0.00300
# 2018-02-01 04:00:00+01:00        0.02573
# 2018-02-01 05:00:00+01:00        0.02334
# ...                                  ...
# 2021-04-22 10:00:00+02:00        0.02250
# 2021-04-22 11:00:00+02:00        0.02240
# 2021-04-22 12:00:00+02:00        0.03157
# 2021-04-22 13:00:00+02:00        0.03151
# 2021-04-22 14:00:00+02:00        0.02500
#
# [28584 rows x 1 columns]

# %%
spot.tz_localize(None)
# Out:
#                      NO4_spot
# time
# 2018-02-01 00:00:00   0.02552
# 2018-02-01 01:00:00   0.02558
# 2018-02-01 02:00:00   0.02553
# 2018-02-01 03:00:00   0.02573
# 2018-02-01 04:00:00   0.02684
# ...                       ...
# 2021-04-22 08:00:00   0.02250
# 2021-04-22 09:00:00   0.02240
# 2021-04-22 10:00:00   0.02204
# 2021-04-22 11:00:00   0.02200
# 2021-04-22 12:00:00   0.02171
#
# [28584 rows x 1 columns]

# %%
spot.index = pd.to_datetime(spot.index, utc=True).tz_convert('Europe/Stockholm')

# %%
spot
# Out:
#                            NO4_spot
# time
# 2018-02-01 01:00:00+01:00   0.02552
# 2018-02-01 02:00:00+01:00   0.02558
# 2018-02-01 03:00:00+01:00   0.02553
# 2018-02-01 04:00:00+01:00   0.02573
# 2018-02-01 05:00:00+01:00   0.02684
# ...                             ...
# 2021-04-22 10:00:00+02:00   0.02250
# 2021-04-22 11:00:00+02:00   0.02240
# 2021-04-22 12:00:00+02:00   0.02204
# 2021-04-22 13:00:00+02:00   0.02200
# 2021-04-22 14:00:00+02:00   0.02171
#
# [28584 rows x 1 columns]

# %%
df_comb.tz_convert(None)
# Out:
#                      Temp Delta__
# date
# 2020-05-31 22:00:00         -0.25
# 2020-05-31 23:00:00         -0.43
# 2020-06-01 00:00:00         -0.60
# 2020-06-01 01:00:00         -0.64
# 2020-06-01 02:00:00         -0.60
# ...                           ...
# 2020-08-30 17:00:00          0.33
# 2020-08-30 18:00:00          0.14
# 2020-08-30 19:00:00          0.04
# 2020-08-30 20:00:00          0.16
# 2020-08-30 21:00:00          0.61
#
# [2184 rows x 1 columns]

# %%
df_comb.index = pd.to_datetime(df_comb.index, utc=True).tz_convert('Europe/Stockholm')

# %%
df_comb
# Out:
#                            Temp Delta__
# date
# 2020-06-01 00:00:00+02:00         -0.25
# 2020-06-01 01:00:00+02:00         -0.43
# 2020-06-01 02:00:00+02:00         -0.60
# 2020-06-01 03:00:00+02:00         -0.64
# 2020-06-01 04:00:00+02:00         -0.60
# ...                                 ...
# 2020-08-30 19:00:00+02:00          0.33
# 2020-08-30 20:00:00+02:00          0.14
# 2020-08-30 21:00:00+02:00          0.04
# 2020-08-30 22:00:00+02:00          0.16
# 2020-08-30 23:00:00+02:00          0.61
#
# [2184 rows x 1 columns]

# %%
df_plot = pd.merge(df_comb, spot , left_index=True, right_index=True, how='inner')
df_plot
# Out:
#                            Temp Delta__  NO4_spot
# 2020-06-01 00:00:00+02:00         -0.25   0.00454
# 2020-06-01 01:00:00+02:00         -0.43   0.00416
# 2020-06-01 02:00:00+02:00         -0.60   0.02650
# 2020-06-01 03:00:00+02:00         -0.64   0.02701
# 2020-06-01 04:00:00+02:00         -0.60   0.02706
# ...                                 ...       ...
# 2020-08-30 19:00:00+02:00          0.33   0.01114
# 2020-08-30 20:00:00+02:00          0.14   0.01121
# 2020-08-30 21:00:00+02:00          0.04   0.01123
# 2020-08-30 22:00:00+02:00          0.16   0.01109
# 2020-08-30 23:00:00+02:00          0.61   0.01093
#
# [2078 rows x 2 columns]

# %%
df_plot = pd.merge(df_plot, imbalance, left_index=True, right_index=True, how='inner')
df_plot
# Out:
#                            Temp Delta__  NO4_spot  NO4_imbalance
# 2020-06-01 00:00:00+02:00         -0.25   0.00454        0.01200
# 2020-06-01 01:00:00+02:00         -0.43   0.00416        0.00667
# 2020-06-01 02:00:00+02:00         -0.60   0.02650        0.02650
# 2020-06-01 03:00:00+02:00         -0.64   0.02701        0.02500
# 2020-06-01 04:00:00+02:00         -0.60   0.02706        0.02400
# ...                                 ...       ...            ...
# 2020-08-30 19:00:00+02:00          0.33   0.01114        0.01114
# 2020-08-30 20:00:00+02:00          0.14   0.01121        0.01480
# 2020-08-30 21:00:00+02:00          0.04   0.01123        0.01480
# 2020-08-30 22:00:00+02:00          0.16   0.01109        0.01433
# 2020-08-30 23:00:00+02:00          0.61   0.01093        0.01093
#
# [2078 rows x 3 columns]

# %%
df_plot.columns
# Out:
# Index(['Temp Delta__', 'NO4_spot', 'NO4_imbalance'], dtype='object')

# %%
df_plot['Direction']= df_plot['NO4_spot']-df_plot['NO4_imbalance']

# %%
df_plot
# Out:
#                            Temp Delta__  NO4_spot  NO4_imbalance  Direction
# 2020-06-01 00:00:00+02:00         -0.25   0.00454        0.01200   -0.00746
# 2020-06-01 01:00:00+02:00         -0.43   0.00416        0.00667   -0.00251
# 2020-06-01 02:00:00+02:00         -0.60   0.02650        0.02650    0.00000
# 2020-06-01 03:00:00+02:00         -0.64   0.02701        0.02500    0.00201
# 2020-06-01 04:00:00+02:00         -0.60   0.02706        0.02400    0.00306
# ...                                 ...       ...            ...        ...
# 2020-08-30 19:00:00+02:00          0.33   0.01114        0.01114    0.00000
# 2020-08-30 20:00:00+02:00          0.14   0.01121        0.01480   -0.00359
# 2020-08-30 21:00:00+02:00          0.04   0.01123        0.01480   -0.00357
# 2020-08-30 22:00:00+02:00          0.16   0.01109        0.01433   -0.00324
# 2020-08-30 23:00:00+02:00          0.61   0.01093        0.01093    0.00000
#
# [2078 rows x 4 columns]

# %%
df_plot.drop(['NO4_spot', 'NO4_imbalance'], axis=1, inplace=True)

# %%
df_plot.index.name="Date"

# %%
df_plot
# Out:
#                            Temp Delta__  Direction
# Date
# 2020-06-01 00:00:00+02:00         -0.25   -0.00746
# 2020-06-01 01:00:00+02:00         -0.43   -0.00251
# 2020-06-01 02:00:00+02:00         -0.60    0.00000
# 2020-06-01 03:00:00+02:00         -0.64    0.00201
# 2020-06-01 04:00:00+02:00         -0.60    0.00306
# ...                                 ...        ...
# 2020-08-30 19:00:00+02:00          0.33    0.00000
# 2020-08-30 20:00:00+02:00          0.14   -0.00359
# 2020-08-30 21:00:00+02:00          0.04   -0.00357
# 2020-08-30 22:00:00+02:00          0.16   -0.00324
# 2020-08-30 23:00:00+02:00          0.61    0.00000
#
# [2078 rows x 2 columns]

# %%
df_plot.columns
# Out:
# Index(['Temp Delta__', 'Direction'], dtype='object')

# %%
df_plot['Direction'] = df_plot['Direction'].apply(lambda x: x*1000)

# %%
df_plot
# Out:
#                            Temp Delta__  Direction
# Date
# 2020-06-01 00:00:00+02:00         -0.25      -7.46
# 2020-06-01 01:00:00+02:00         -0.43      -2.51
# 2020-06-01 02:00:00+02:00         -0.60       0.00
# 2020-06-01 03:00:00+02:00         -0.64       2.01
# 2020-06-01 04:00:00+02:00         -0.60       3.06
# ...                                 ...        ...
# 2020-08-30 19:00:00+02:00          0.33       0.00
# 2020-08-30 20:00:00+02:00          0.14      -3.59
# 2020-08-30 21:00:00+02:00          0.04      -3.57
# 2020-08-30 22:00:00+02:00          0.16      -3.24
# 2020-08-30 23:00:00+02:00          0.61       0.00
#
# [2078 rows x 2 columns]

# %%
df_plot.columns
# Out:
# Index(['Temp Delta__', 'Direction'], dtype='object')

# %%
df_plot['Temp Delta__'].astype('float64')
# Out:
# Date
# 2020-06-01 00:00:00+02:00   -0.25
# 2020-06-01 01:00:00+02:00   -0.43
# 2020-06-01 02:00:00+02:00   -0.60
# 2020-06-01 03:00:00+02:00   -0.64
# 2020-06-01 04:00:00+02:00   -0.60
#                              ...
# 2020-08-30 19:00:00+02:00    0.33
# 2020-08-30 20:00:00+02:00    0.14
# 2020-08-30 21:00:00+02:00    0.04
# 2020-08-30 22:00:00+02:00    0.16
# 2020-08-30 23:00:00+02:00    0.61
# Name: Temp Delta__, Length: 2078, dtype: float64

# %%
df_plot['Direction'].astype('float64')
# Out:
# Date
# 2020-06-01 00:00:00+02:00   -7.46
# 2020-06-01 01:00:00+02:00   -2.51
# 2020-06-01 02:00:00+02:00    0.00
# 2020-06-01 03:00:00+02:00    2.01
# 2020-06-01 04:00:00+02:00    3.06
#                              ...
# 2020-08-30 19:00:00+02:00    0.00
# 2020-08-30 20:00:00+02:00   -3.59
# 2020-08-30 21:00:00+02:00   -3.57
# 2020-08-30 22:00:00+02:00   -3.24
# 2020-08-30 23:00:00+02:00    0.00
# Name: Direction, Length: 2078, dtype: float64

# %%
blue = sns.color_palette("muted", desat=0.9)[0]
green = sns.color_palette("muted", desat=0.9)[2]
red = sns.color_palette("muted", desat=0.9)[3]
grey = sns.color_palette("muted", desat=0.9)[7]

# %%
# fig, ax1 = plt.subplots(figsize=[20,7])

# x = df_plot.index
# plt.xlabel("Timestamp")
# plt.ylabel("Temp Delta", fontsize=12, color=red);
# y1 = df_plot['Temp Delta__']
# y2 = df_plot['Direction']

# ax2 = ax1.twinx()

# ax1.scatter(x, y1, alpha=0.6, lw=4, color=red)
# plt.ylabel("Direction of Market", fontsize=12, color=blue);
# ax2.scatter(x, y2, alpha=0.6, lw=4, color=blue)
# ax1.invert_yaxis()
# ax2.invert_yaxis()
# plt.autoscale();

# %%
fig= plt.figure(figsize=[12,5])
plt.scatter(x=df_plot['Temp Delta__'],
            y=df_plot['Direction'],
            alpha=0.3,
            s=75,
            color=red);
plt.grid()
plt.xlabel("Temperature Delta", fontsize=12),
plt.ylabel("Direction of Market", fontsize=12);
plt.title("Direction of Market v/s Temperature Delta (NO4 Summer)");
plt.autoscale();
